# %%
from langchain_core.documents import Document

doc = Document(
      page_content = "Hello This is Saravana , Software developer in Slate.ai, Banglore. I'm good in React,Postgres, Node,Express,Hasura Graphql, Python , Rest APi",
      metadata={
        "source":"Saravana.txt",
        "author":"Saravana",
        "created_on":"2026-08-22"
      }
)

# %%
doc
# Out:
# Document(metadata={'source': 'Saravana.txt', 'author': 'Saravana', 'created_on': '2026-08-22'}, page_content="Hello This is Saravana , Software developer in Slate.ai, Banglore. I'm good in React,Postgres, Node,Express,Hasura Graphql, Python , Rest APi")
